# %%
import pandas as pd
import numpy as np

import random
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
histogram
rugplot
kde
barplot

# %%
data = np.random.randn(100)

# %%
# Histogram

plt.hist(data, bins= 10, range=(-2,2), density=False, 
         weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', 
         orientation='vertical', rwidth=None, log=False, color='indianred', label='First Histogram', 
         stacked=True)
# Out:
# (array([ 2.,  7., 11., 14., 21., 15.,  8.,  7.,  8.,  3.]),
#  array([-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data)  # Histogram with KDE

# %%
sns.distplot(data, kde=False, rug=True)  # Histogram with rug but without KDE

# %%
sns.rugplot(data)

# %%
# Bar

sns.barplot(x=['jobs','queries'], y=[30, 89])

# %%
sns.distplot(data, normed=True, color='indianred', alpha=0.5, bins=20)
sn

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
sns.set(style="whitegrid")

# Load the example Titanic dataset
titanic = sns.load_dataset("titanic")
g = sns.catplot(x="class", y="survived", hue="sex", data=titanic,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("survival probability")
