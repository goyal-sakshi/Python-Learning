# %%
import pandas as pd
import numpy as np
df = pd.read_csv('files/weather_report_2.csv')
#df.set_index('city', inplace=True)

# %%
df[(df['city']=='NY') & (df['temp']==36)]
# Out:
#   city  temp  windspeed  event
# 1   NY    36          7  Sunny

# %%
ss = 'acb,aewfs.txt'
s = ss.split(',')
s[1].rsplit('.',1)[0]
ll = ['NY',377,6,'Rain']

# %%
df
# Out:
# Empty DataFrame
# Columns: [city, temp, windspeed, event]
# Index: []

# %%
if ll[0] in  list(df['city']):
    gb = df.groupby('city')
    if not ll[1] in list(gb.get_group(ll[0])['temp']):
        print 'ok'

# %%
dd = df.loc[(df['temp']==28) & (df['event']=='Sunny')]
list(dd['city'])[0]
# Out:
# 'NY'

# %%
ss ='abc-QAF-abc-QAF--QAF--QAF-abc-QAF-'
ff = ss.split('-QAF-')
ff
if not ff[2]:
    print 'ok'
# Out:
# ok

# %%
import os
os.getcwd()
os.path.dirname(__file__) # relative directory path
os.path.abspath(__file__) # absolute file path
os.path.basename(__file__) # the file name only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9d1f2a970037> in <module>()
#       1 import os
#       2 os.getcwd()
# ----> 3 os.path.dirname(__file__) # relative directory path
#       4 os.path.abspath(__file__) # absolute file path
#       5 os.path.basename(__file__) # the file name only
#
# NameError: name '__file__' is not defined

# %%
gb = df.groupby('city')
# SELECT * FROM city_data GROUPBY city
for i,j in gb:
    #newdf = j.iloc[:,1:]
    print j.pivot(index='city', columns='windspeed', values='event')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-90381c827fb3> in <module>()
# ----> 1 gb = df.groupby('city')
#       2 # SELECT * FROM city_data GROUPBY city
#       3 for i,j in gb:
#       4     #newdf = j.iloc[:,1:]
#       5     print j.pivot(index='city', columns='windspeed', values='event')
#
# NameError: name 'df' is not defined

# %%
gb = df.groupby('city')
gb.groups.keys()
# Out:
# ['Paris', 'NY', 'Mumbai']

# %%
df.style.highlight_null().render().split('\n')
# Out:
# [u'<style  type="text/css" >',
#  u'</style>  ',
#  u'<table id="T_0d0ed076_9f9b_11e8_aad2_90324b783997" > ',
#  u'<thead>    <tr> ',
#  u'        <th class="blank level0" ></th> ',
#  u'        <th class="col_heading level0 col0" >day</th> ',
#  u'        <th class="col_heading level0 col1" >city</th> ',
#  u'        <th class="col_heading level0 col2" >temp</th> ',
#  u'        <th class="col_heading level0 col3" >windspeed</th> ',
#  u'        <th class="col_heading level0 col4" >event</th> ',
#  u'    </tr></thead> ',
#  u'<tbody>    <tr> ',
#  u'        <th id="T_0d0ed076_9f9b_11e8_aad2_90324b783997level0_row0" class="row_heading level0 row0" >0</th> ',
#  u'        <td id="T_0d0ed076_9f9b_11e8_aad2_90324b783997row0_col0" class="data row0 col0" >01/01/17</td> ',
#  u'        <td id="T_0d0ed076_9f9b_11e8_aad2_90324b783997row0_col1" class="data row0 col1" >NY</td> ',
#  u'        <td id="T_0d0ed076_9f9b_11e8_aad2_90324b783997row0_col2" class="data row0 col2" >32</td> ',
# ...

# %%
gb = df.groupby('city').apply(lambda x: x.sort_values('temp'))
# SELECT * FROM city_data GROUPBY city

df
# Out:
#      city  temp  windspeed   event
# 0      NY    32          6    Rain
# 1      NY    36          7   Sunny
# 2      NY    28         12   Sunny
# 3      NY    32          6    Rain
# 4  Mumbai    90          5   Sunny
# 5  Mumbai    85         12     Fog
# 6   Paris    87         15     Fog
# 7   Paris    56          5  Cloudy
# 8   Paris    78          5  Cloudy
# 9   Paris    76         20  Cloudy

# %%
df.drop_duplicates(['city', 'temp'], inplace=True)

# %%
for i,r in df.iterrows():
    print (r['city'], r['temp'])
# Out:
# ('NY', 32)
# ('NY', 36)
# ('NY', 28)
# ('Mumbai', 90)
# ('Mumbai', 85)
# ('Paris', 87)
# ('Paris', 56)
# ('Paris', 78)
# ('Paris', 76)

# %%
subset = df[['city', 'temp']]
tuples = [tuple(x) for x in subset.values]
tuples
# Out:
# [('NY', 32),
#  ('NY', 36),
#  ('NY', 28),
#  ('Mumbai', 90),
#  ('Mumbai', 85),
#  ('Paris', 87),
#  ('Paris', 56),
#  ('Paris', 78),
#  ('Paris', 76)]

# %%
zip([tuple(x) for x in subset.values])
# Out:
# [(('NY', 32),),
#  (('NY', 36),),
#  (('NY', 28),),
#  (('Mumbai', 90),),
#  (('Mumbai', 85),),
#  (('Paris', 87),),
#  (('Paris', 56),),
#  (('Paris', 78),),
#  (('Paris', 76),)]

# %%
def cal_diff():
    return 

gb.get_group('Mumbai').mean().temp
# Out:
# 87.5

# %%
from IPython.display import Image, YouTubeVideo
img = Image('/home/sa.goyal/Pictures/Selection_002.png')
img

# %%
#### SPLIT APPLY COMBINE

gb.max()
# Out:
#              day  temp  windspeed  event
# city
# Mumbai  01/06/17    90         12  Sunny
# NY      01/04/17    36         12  Sunny
# Paris   01/07/17    87         20    Fog

# %%
gb.mean().temp
# Out:
# city
# Mumbai    87.50
# NY        32.25
# Paris     74.25
# Name: temp, dtype: float64

# %%
gb.describe()
# Out:
#         temp                                                   windspeed  \
#        count   mean        std   min    25%   50%    75%   max     count
# city
# Mumbai   2.0  87.50   3.535534  85.0  86.25  87.5  88.75  90.0       2.0
# NY       4.0  32.25   3.304038  28.0  31.00  32.5  33.75  36.0       4.0
# Paris    4.0  74.25  13.073510  56.0  71.00  77.0  80.25  87.0       4.0
#
#
#          mean       std  min   25%   50%    75%   max
# city
# Mumbai   8.50  4.949747  5.0  6.75   8.5  10.25  12.0
# NY       8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# Paris   11.25  7.500000  5.0  5.00  10.0  16.25  20.0

# %%
#%matplotlib inline
import matplotlib
gb.plot()
# Out:
# city
# Mumbai    AxesSubplot(0.125,0.125;0.775x0.755)
# NY        AxesSubplot(0.125,0.125;0.775x0.755)
# Paris     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
india_weather = pd.DataFrame({
    'city': [np.nan, 'Two', 'Three', 'Four', 'One'],
    'temp': [20,40,20,321,12],
    'fog': [20,10,5,213,12]
})

# %%
set(india_weather['city'])
# Out:
# {'', 'Four', 'One', 'Three', 'Two'}

# %%
india_weather.to_html().replace('<tr>\n      <th>','<ef>')
# Out:
# u'<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>city</th>\n      <th>fog</th>\n      <th>temp</th>\n    </tr>\n  </thead>\n  <tbody>\n    <ef>0</th>\n      <td></td>\n      <td>20</td>\n      <td>20</td>\n    </tr>\n    <ef>1</th>\n      <td>Two</td>\n      <td>10</td>\n      <td>40</td>\n    </tr>\n    <ef>2</th>\n      <td>Three</td>\n      <td>5</td>\n      <td>20</td>\n    </tr>\n    <ef>3</th>\n      <td>Four</td>\n      <td>213</td>\n      <td>321</td>\n    </tr>\n    <ef>4</th>\n      <td>One</td>\n      <td>12</td>\n      <td>12</td>\n    </tr>\n  </tbody>\n</table>'

# %%
india_weather.fillna('', inplace=True)

# %%
ss = pd.Series(['a','a',np.nan], index=['city','temp','fog'])
india_weather = india_weather.append(ss, ignore_index=True)
type(india_weather['city'][1])
# Out:
# str

# %%
india_weather.columns
# Out:
# Index([u'city', u'fog', u'temp'], dtype='object')

# %%
india_weather.loc[india_weather['fog'] == india_weather['temp']]
# Out:
#   city  fog  temp
# 0        20    20
# 4  One   12    12

# %%
india_weather['city'].replace(np.nan,'ok', inplace=True)

# %%
india_weather.loc[india_weather['city'].isin([np.nan])]
# Out:
#   city   fog temp
# 0  NaN  20.0   20

# %%
tf = india_weather['city'].isin(l1)
l1 = set(india_weather['city']) - set(l1)
l1
# Out:
# {nan, 'Four', 'One', 'Three', 'Two', 'a'}

# %%
india_weather
# Out:
#     city  fog  temp
# 0    One   20    20
# 1    Two   10    40
# 2  Three    5    20
# 3   Four  213   321
# 4    One   12    12

# %%
for f in tf:
    if not f:
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: city, dtype: bool

# %%
for i in range(0,len(l1)):
    
    if i==0:
        x = india_weather['city'].isin([l1[i]])
        print x
    else:
        x = x | india_weather['city'].isin([l1[i]])
        print x
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: city, dtype: bool
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: city, dtype: bool
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: city, dtype: bool
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: city, dtype: bool
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: city, dtype: bool

# %%
aa=True
bb=False
aa|bb
# Out:
# True

# %%
india_weather.loc['Mumbai']
# Out:
# fog     20
# temp    30
# Name: Mumbai, dtype: int64

# %%
us_weather = pd.DataFrame({
    'city': ['NONE','NONE','Orlando4'],
    'fog': [20,10,15]
})


# temp_df = pd.DataFrame({'flag':[True,False,False]})
# print temp_df
# us_weather[temp_df['flag']] = 'k'
us_weather
# Out:
#        city  fog
# 0      NONE   20
# 1      NONE   10
# 2  Orlando4   15

# %%
us_weather['city'] = us_weather['city'].replace('\d+$','', regex=True)
us_weather
# Out:
#       city  fog
# 0     NONE   20
# 1     NONE   10
# 2  Orlando   15

# %%
ll
# Out:
# total 1040
# -rw-rw-r-- 1 sa.goyal   5013 Aug 20 15:27 bar1.png
# -rw-rw-r-- 1 sa.goyal   5013 Aug 20 15:13 bar.png
# -rw-rw-r-- 1 sa.goyal 107296 Nov  2 16:04 DataFrame.ipynb
# drwxrwxr-x 3 sa.goyal   4096 Sep 12 13:57 files/
# -rw-rw-r-- 1 sa.goyal  38393 Aug 28 17:07 Matplotlib.ipynb
# -rw-rw-r-- 1 sa.goyal 119834 Oct 11 16:20 Pandas_Level_1.ipynb
# -rw-rw-r-- 1 sa.goyal 130901 Aug 13 10:21 Pandas_Level_2.ipynb
# -rw-rw-r-- 1 sa.goyal   4808 Oct 11 19:04 Series.ipynb
# -rw-rw-r-- 1 sa.goyal  24239 Sep 12 13:08 StocksWeatherExcel.ipynb
# -rw-rw-r-- 1 sa.goyal   7850 Aug 20 15:33 test.pdf
# -rw-rw-r-- 1 sa.goyal  50241 Jul 16 15:40 TimeSeries2.ipynb
# -rw-rw-r-- 1 sa.goyal  87992 Aug 13 17:57 TimeSeries.ipynb
# -rw-rw-r-- 1 sa.goyal   1637 Sep 19 14:25 Untitled1.ipynb
# -rw-rw-r-- 1 sa.goyal  27807 Aug 13 15:27 Untitled.ipynb
# -rw-rw-r-- 1 sa.goyal 341151 Nov 12 17:36 WeatherReport2Csv.ipynb
# -rw-rw-r-- 1 sa.goyal  75604 Aug 10 11:44 WeatherReportCsv.ipynb

# %%
#m = map(lambda x,y: x==y,us_weather['city'],us_weather['temp'])

n = pd.Series([True, False, True])
us_weather.loc[n] = us_weather['fog']
us_weather
# Out:
#    city fog
# 0    15  15
# 1  NONE  10
# 2    15  15

# %% [markdown]
# another_df = SovMap.loc[Key_column_of_dictonary=[RatingToUseBorder[UsdSovTable & SovMap.iskey(RatingToUseBorder)]]]
# another_df['Values_of_dictionary_in_df']

# %%
df1 = pd.DataFrame(data = {'col1' : [1, 2, 3, 4, 5], 'col2' : [10, 11, 12, 13, 14]}) 
df2 = pd.DataFrame(data = {'col1' : [1, 2, 3], 'col2' : [10, 11, 12]})

# %%
df1
# Out:
#    col1  col2
# 0     1    10
# 1     2    11
# 2     3    12
# 3     4    13
# 4     5    14
# 0     1    10
# 1     2    11
# 2     3    12

# %%
df2
# Out:
#    col1  col2
# 0     1    10
# 1     2    11
# 2     3    12

# %%
df1 = df1.append(df2)
india_weather
# Out:
#            temp
# city  fog
# One   20     20
# Two   10     40
# Three 5      20
# Four  213   321
# One   12     12

# %%
pd.Series(india_weather.index.get_values())
# Out:
# 0      (One, 20)
# 1      (Two, 10)
# 2     (Three, 5)
# 3    (Four, 213)
# 4      (One, 12)
# dtype: object

# %%
india_weather.set_index('city', inplace=True)
print india_weather.index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-78eec29d3af7> in <module>()
# ----> 1 india_weather.set_index('city', inplace=True)
#       2 print india_weather.index
#
# /home/sa.goyal/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3904                 names.append(None)
#    3905             else:
# -> 3906                 level = frame[col]._values
#    3907                 names.append(col)
#    3908                 if drop:
#
# /home/sa.goyal/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ...

# %%
us_weather.set_index(['city','fog'], inplace=True)

# %%
india_weather.merge(us_weather, on=['city','fog'])
# Out:
#   city  fog  temp
# 0   NY   20    20

# %%
india_weather[india_weather.loc[:,:2].isin(us_weather)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-9e8ec5d6ec03> in <module>()
# ----> 1 india_weather[india_weather.loc[:,:2].isin(us_weather)]
#
# /home/sa.goyal/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /home/sa.goyal/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# ...

# %%
india_weather.merge(us_weather, on=['city', 'fog'], how='inner')
# Out:
#   city  fog  temp_x  temp_y
# 0   NY   20      20       5

# %%
#df_India_US = pd.concat([india_weather, us_weather], keys=['a','b'])
dfinal = india_weather.merge(us_weather, on="city", how = 'outer')
dfinal.iloc[:,0:1]
# Out:
#          city
# 0      Mumbai
# 1       Delhi
# 2  Chandigarh
# 3          NY
# 4     Chicago
# 5     Orlando

# %%
df_India_US.loc['India']
# Out:
#          city  fog  temp
# 0      Mumbai   20    30
# 1       Delhi   10    40
# 2  Chandigarh    5    20

# %%
temp_df = pd.DataFrame({
    'city': ['Mumbai','Delhi','Chandigarh'],
    'fog': [20.6,30.58,10.23],
    'temp': [30,40,20]
})
temp_df.set_index('city', inplace=True)
temp_df
# Out:
#               fog  temp
# city
# Mumbai      20.60    30
# Delhi       30.58    40
# Chandigarh  10.23    20

# %%
fog_df = pd.DataFrame({
    'city': ['Delhi','Mumbai'],
    'fog': [28734141241.525,12441535.3553150],
    'temp': [32533,4052346626]
})
fog_df.set_index('city', inplace=True)
fog_df['fog'] = fog_df['fog'].apply(lambda x: '{:.0f}'.format(x))
fog_df
# Out:
#                 fog        temp
# city
# Delhi   28734141242       32533
# Mumbai     12441535  4052346626

# %%
fog_df['fog'] = fog_df['fog'].astype('int64')
fog_df.shape[0]
# Out:
# 2

# %%
merged_Frame = pd.merge(temp_df,fog_df, on='city', how='inner')
merged_Frame
# Out:
#         fog_x  temp_x  fog_y  temp_y
# city
# Mumbai     20      30     30      40
# Delhi      30      40     20      30

# %%
## JOINS

df_temp_fog = pd.concat([temp_df, fog_df])
df_temp_fog
# Out:
#             fog  temp
# city
# Mumbai       20    30
# Delhi        30    40
# Chandigarh   10    20
# Delhi        20    30
# Mumbai       30    40

# %%
ser_country = pd.Series(['India', 'India','India'], name='country')
ser_country
# Out:
# 0    India
# 1    India
# 2    India
# Name: country, dtype: object

# %%
df_ = pd.concat([df_temp_fog, ser_country])
df_
# Out:
#        0        city   fog  temp
# 0    NaN      Mumbai  20.0  30.0
# 1    NaN       Delhi  30.0  40.0
# 2    NaN  Chandigarh  10.0  20.0
# 0    NaN       Delhi  20.0  30.0
# 1    NaN      Mumbai  30.0  40.0
# 0  India         NaN   NaN   NaN
# 1  India         NaN   NaN   NaN
# 2  India         NaN   NaN   NaN

# %%
### INNER JOIN

df_inner = pd.merge(temp_df, fog_df, on='city')
df_inner
# Out:
#          city  temp  fog
# 0      Mumbai    30   30
# 1       Delhi    40   20
# 2  Chandigarh    20   10

# %%
df1 = pd.DataFrame({
    'city': ['Mumbai','Gurgaun','Chandigarh'],
    'temp': [30,40,20]
})
df1
# Out:
#          city  temp
# 0      Mumbai    30
# 1     Gurgaun    40
# 2  Chandigarh    20

# %%
df2 = pd.DataFrame({
    'city': ['Mumbai','Delhi','Chandigarh','Kolkata'],
    'temp': [30,40,20,98]
})
df2
# Out:
#          city  temp
# 0      Mumbai    30
# 1       Delhi    40
# 2  Chandigarh    20
# 3     Kolkata    98

# %%
### OUTER JOIN

df_outer = pd.merge(df1, df2, on='city', how='outer', indicator=True, suffixes=['_left','_right'])
df_outer
# Out:
#          city  temp_left  temp_right      _merge
# 0      Mumbai       30.0        30.0        both
# 1     Gurgaun       40.0         NaN   left_only
# 2  Chandigarh       20.0        20.0        both
# 3       Delhi        NaN        40.0  right_only
# 4     Kolkata        NaN        98.0  right_only

# %%
df
# Out:
#             city  temp  windspeed   event
# day
# 01/01/17      NY    32          6    Rain
# 01/02/17      NY    36          7   Sunny
# 01/03/17      NY    28         12   Sunny
# 01/04/17      NY    33          7   Sunny
# 01/05/17  Mumbai    90          5   Sunny
# 01/06/17  Mumbai    85         12     Fog
# 01/01/17   Paris    87         15     Fog
# 01/03/17   Paris    56          5  Cloudy
# 01/05/17   Paris    78          5  Cloudy
# 01/07/17   Paris    76         20  Cloudy

# %%
df_pivot = df.pivot(index='day', columns='city')
df_pivot
# Out:
#            temp             windspeed              event
# city     Mumbai    NY Paris    Mumbai    NY Paris Mumbai     NY   Paris
# day
# 01/01/17    NaN  32.0  87.0       NaN   6.0  15.0    NaN   Rain     Fog
# 01/02/17    NaN  36.0   NaN       NaN   7.0   NaN    NaN  Sunny     NaN
# 01/03/17    NaN  28.0  56.0       NaN  12.0   5.0    NaN  Sunny  Cloudy
# 01/04/17    NaN  33.0   NaN       NaN   7.0   NaN    NaN  Sunny     NaN
# 01/05/17   90.0   NaN  78.0       5.0   NaN   5.0  Sunny    NaN  Cloudy
# 01/06/17   85.0   NaN   NaN      12.0   NaN   NaN    Fog    NaN     NaN
# 01/07/17    NaN   NaN  76.0       NaN   NaN  20.0    NaN    NaN  Cloudy

# %%
df_piv = df.pivot(index='day', columns='city', values='temp')
df_piv
# Out:
# city      Mumbai    NY  Paris
# day
# 01/01/17     NaN  32.0   87.0
# 01/02/17     NaN  36.0    NaN
# 01/03/17     NaN  28.0   56.0
# 01/04/17     NaN  33.0    NaN
# 01/05/17    90.0   NaN   78.0
# 01/06/17    85.0   NaN    NaN
# 01/07/17     NaN   NaN   76.0

# %%
#### by default gives the output of the average of the values having same index
# 01/01/17 -> temp=32
# 01/01/17 -> temp=35

# output -> temp = mean(32,35)              --operation     --All
df.pivot_table(index='day', columns='city', aggfunc='sum', margins=True)
# Out:
#            temp                    windspeed
# city     Mumbai     NY  Paris  All    Mumbai    NY Paris All
# day
# 01/01/17    NaN   32.0   87.0  119       NaN   6.0  15.0  21
# 01/02/17    NaN   36.0    NaN   36       NaN   7.0   NaN   7
# 01/03/17    NaN   28.0   56.0   84       NaN  12.0   5.0  17
# 01/04/17    NaN   33.0    NaN   33       NaN   7.0   NaN   7
# 01/05/17   90.0    NaN   78.0  168       5.0   NaN   5.0  10
# 01/06/17   85.0    NaN    NaN   85      12.0   NaN   NaN  12
# 01/07/17    NaN    NaN   76.0   76       NaN   NaN  20.0  20
# All       175.0  129.0  297.0  601      17.0  32.0  45.0  94

# %%
df.day = pd.to_datetime(df.day)
#df.set_index('day', inplace=True)
type(df.day)
# Out:
# pandas.core.series.Series

# %%
#### groups the index via month -> 'M', gives the avg of whole month
df.pivot_table(index=pd.Grouper(freq='M', key='day'), columns='city')
df
# Out:
#          day    city  temp  windspeed   event
# 0 2017-01-01      NY    32          6    Rain
# 1 2017-01-02      NY    36          7   Sunny
# 2 2017-01-03      NY    28         12   Sunny
# 3 2017-01-04      NY    33          7   Sunny
# 4 2017-01-05  Mumbai    90          5   Sunny
# 5 2017-01-06  Mumbai    85         12     Fog
# 6 2017-01-01   Paris    87         15     Fog
# 7 2017-01-03   Paris    56          5  Cloudy
# 8 2017-01-05   Paris    78          5  Cloudy
# 9 2017-01-07   Paris    76         20  Cloudy

# %%
df_melt = pd.DataFrame({
    'day': ['Mon','Tues','Wed','Thrus','Fri','Sat','Sun'],
    'chicago': [40,50,60,79,47,57,66],
    'NY': [24,23,56,65,44,45,56],
    'Orlando': [32,34,12,44,45,66,57]
})
df_melt
# Out:
#    NY  Orlando  chicago    day
# 0  24       32       40    Mon
# 1  23       34       50   Tues
# 2  56       12       60    Wed
# 3  65       44       79  Thrus
# 4  44       45       47    Fri
# 5  45       66       57    Sat
# 6  56       57       66    Sun

# %%
df_melt = pd.melt(df_melt, id_vars='day', var_name='city', value_name='temp')
df_melt
# Out:
#       day  city     temp
# 0     Mon  city       NY
# 1    Tues  city       NY
# 2     Wed  city       NY
# 3   Thrus  city       NY
# 4     Fri  city       NY
# 5     Sat  city       NY
# 6     Sun  city       NY
# 7     Mon  city  Orlando
# 8    Tues  city  Orlando
# 9     Wed  city  Orlando
# 10  Thrus  city  Orlando
# 11    Fri  city  Orlando
# 12    Sat  city  Orlando
# 13    Sun  city  Orlando
# 14    Mon  city  chicago
# 15   Tues  city  chicago
# 16    Wed  city  chicago
# 17  Thrus  city  chicago
# 18    Fri  city  chicago
# 19    Sat  city  chicago
# 20    Sun  city  chicago
# 21    Mon  temp       24
# 22   Tues  temp       23
# 23    Wed  temp       56
# 24  Thrus  temp       65
# 25    Fri  temp       44
# 26    Sat  temp       45
# 27    Sun  temp       56
# 28    Mon  temp       32
# 29   Tues  temp       34
# 30    Wed  temp       12
# 31  Thrus  temp       44
# 32    Fri  temp       45
# 33    Sat  temp       66
# 34    Sun  temp       57
# 35    Mon  temp       40
# ...

# %%
df_excel
# Out:
#            price                     P/E
# company       fb google microsoft     fb google microsoft
# 2017-06-05   155    955        66  37.10   32.0     30.31
# 2017-06-06   657    987        69  36.98   32.3     30.56
# 2017-06-07   354    654        62  36.78   31.0     30.46
# 2017-06-08   353    456        61  36.11   31.0     30.11
# 2017-06-09   543    432        66  37.07   30.0     31.00

# %%
df_excel = pd.read_excel('files/weather_report_3.xlsx', header=[0,1])
df_excel.columns.levels[0]
# Out:
# Index([u'P/E', u'price'], dtype='object')

# %%
df_stacked = df_excel.stack()   # transposes the innermost columns
df_stacked.T
# Out:
#         2017-06-05                  2017-06-06                  2017-06-07  \
# company         fb google microsoft         fb google microsoft         fb
# P/E           37.1   32.0     30.31      36.98   32.3     30.56      36.78
# price        155.0  955.0     66.00     657.00  987.0     69.00     354.00
#
#                          2017-06-08                  2017-06-09         \
# company google microsoft         fb google microsoft         fb google
# P/E       31.0     30.46      36.11   31.0     30.11      37.07   30.0
# price    654.0     62.00     353.00  456.0     61.00     543.00  432.0
#
#
# company microsoft
# P/E          31.0
# price        66.0

# %%
df_stack = df_excel.stack(level=0)
df_stack
# Out:
# company               fb  google  microsoft
# 2017-06-05 P/E     37.10    32.0      30.31
#            price  155.00   955.0      66.00
# 2017-06-06 P/E     36.98    32.3      30.56
#            price  657.00   987.0      69.00
# 2017-06-07 P/E     36.78    31.0      30.46
#            price  354.00   654.0      62.00
# 2017-06-08 P/E     36.11    31.0      30.11
#            price  353.00   456.0      61.00
# 2017-06-09 P/E     37.07    30.0      31.00
#            price  543.00   432.0      66.00

# %%
df_stack = df_stack.unstack()
df_stack
# Out:
# company        fb        google        microsoft
#               P/E  price    P/E  price       P/E price
# 2017-06-05  37.10  155.0   32.0  955.0     30.31  66.0
# 2017-06-06  36.98  657.0   32.3  987.0     30.56  69.0
# 2017-06-07  36.78  354.0   31.0  654.0     30.46  62.0
# 2017-06-08  36.11  353.0   31.0  456.0     30.11  61.0
# 2017-06-09  37.07  543.0   30.0  432.0     31.00  66.0

# %%
df_stack
# Out:
# company        fb        google        microsoft
#               P/E  price    P/E  price       P/E price
# 2017-06-05  37.10  155.0   32.0  955.0     30.31  66.0
# 2017-06-06  36.98  657.0   32.3  987.0     30.56  69.0
# 2017-06-07  36.78  354.0   31.0  654.0     30.46  62.0
# 2017-06-08  36.11  353.0   31.0  456.0     30.11  61.0
# 2017-06-09  37.07  543.0   30.0  432.0     31.00  66.0

# %%
val = df_stack.values
val
# Out:
# array([[ 37.1 , 155.  ,  32.  , 955.  ,  30.31,  66.  ],
#        [ 36.98, 657.  ,  32.3 , 987.  ,  30.56,  69.  ],
#        [ 36.78, 354.  ,  31.  , 654.  ,  30.46,  62.  ],
#        [ 36.11, 353.  ,  31.  , 456.  ,  30.11,  61.  ],
#        [ 37.07, 543.  ,  30.  , 432.  ,  31.  ,  66.  ]])

# %%
[list(i)for i in list(val)]
# Out:
# [[37.1, 155.0, 32.0, 955.0, 30.31, 66.0],
#  [36.98, 657.0, 32.3, 987.0, 30.56, 69.0],
#  [36.78, 354.0, 31.0, 654.0, 30.46, 62.0],
#  [36.11, 353.0, 31.0, 456.0, 30.11, 61.0],
#  [37.07, 543.0, 30.0, 432.0, 31.0, 66.0]]

# %%
df_stack.insert(0,'ok',ll)
# Out:
# company     ok     fb        google        microsoft
#                   P/E  price    P/E  price       P/E price
# 2017-06-05 NaN  37.10  155.0   32.0  955.0     30.31  66.0
# 2017-06-06 NaN  36.98  657.0   32.3  987.0     30.56  69.0
# 2017-06-07 NaN  36.78  354.0   31.0  654.0     30.46  62.0
# 2017-06-08 NaN  36.11  353.0   31.0  456.0     30.11  61.0
# 2017-06-09 NaN  37.07  543.0   30.0  432.0     31.00  66.0

# %%
df_stack
# Out:
# company               fb  google  microsoft
# 2017-06-05 P/E     37.10    32.0      30.31
#            price  155.00   955.0      66.00
# 2017-06-06 P/E     36.98    32.3      30.56
#            price  657.00   987.0      69.00
# 2017-06-07 P/E     36.78    31.0      30.46
#            price  354.00   654.0      62.00
# 2017-06-08 P/E     36.11    31.0      30.11
#            price  353.00   456.0      61.00
# 2017-06-09 P/E     37.07    30.0      31.00
#            price  543.00   432.0      66.00

# %%
seen = set()
seen_add = seen.add
print [x for x in ll if not (x in seen or seen_add(x))]
# Out:
# ['bb', '4', 'aa']

# %%
ll
# Out:
# [nan, nan, nan, nan, nan]

# %%
for i in range(5):
    ll.append(np.nan)
ll
# Out:
# [nan, nan, nan, nan, nan]

# %%
pd.crosstab(df.event, df.city, margins=True)    # frequency
# Out:
# city    Mumbai  NY  Paris  All
# event
# Cloudy       0   0      3    3
# Fog          1   0      1    2
# Rain         0   1      0    1
# Sunny        1   3      0    4
# All          2   4      4   10

# %%
pd.crosstab(df.event, df.city, normalize='index')    # percentage
# Out:
# city    Mumbai    NY  Paris
# event
# Cloudy    0.00  0.00    1.0
# Fog       0.50  0.00    0.5
# Rain      0.00  1.00    0.0
# Sunny     0.25  0.75    0.0

# %%
pd.crosstab([df.city,df.temp], [df.event, df.day])
# Out:
# event           Cloudy                              Fog                  Rain  \
# day         2017-01-03 2017-01-05 2017-01-07 2017-01-01 2017-01-06 2017-01-01
# city   temp
# Mumbai 85            0          0          0          0          1          0
#        90            0          0          0          0          0          0
# NY     28            0          0          0          0          0          0
#        32            0          0          0          0          0          1
#        33            0          0          0          0          0          0
#        36            0          0          0          0          0          0
# Paris  56            1          0          0          0          0          0
#        76            0          0          1          0          0          0
#        78            0          1          0          0          0          0
#        87            0          0          0          1          0          0
#
# ...

# %%
pd.crosstab(df.city, df.event, values=df.temp, aggfunc=np.average)
# Out:
# event   Cloudy   Fog  Rain      Sunny
# city
# Mumbai     NaN  85.0   NaN  90.000000
# NY         NaN   NaN  32.0  32.333333
# Paris     70.0  87.0   NaN        NaN
